# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import hvplot as hv
from PIL import Image
import plotly.express as px

# %%
vendor_terr_names = pd.read_csv('data/vendor_terr_names.csv', sep=',\t', names= ['id', 'name'])
vendor_terr_names.info()
vendor_terr_names.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3303 entries, 0 to 3302
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      3303 non-null   int64
#  1   name    3303 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 51.7+ KB
# /var/folders/fh/yq61fqcs3q9_0k81sxnf4ff40000gn/T/ipykernel_41564/4082966582.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   vendor_terr_names = pd.read_csv('data/vendor_terr_names.csv', sep=',\t', names= ['id', 'name'])
#            id                                           name
# 0     1703200                 Andijon viloyatining tumanlari
# 1  1710237800  Kasbi tumanining qishloq fuqarolar yig‘inlari
# 2  1722210566                                    Paxtakurash
# 3     1703202                               Oltinko‘l tumani
# 4  1710237822                                        Qamashi
# 5  1722210568                                       Namozgoh
# 6  1703202550             Oltinko‘l tumanining shaharchalari
# 7  1710237825                                        Komilon
# 8  1722210572                                        Jamatak
# 9  1703202552                                        Bo‘ston

# %%
resultat = pd.read_csv('data/resultat_method.csv', sep=',')
resultat.info()
resultat.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 552096 entries, 0 to 552095
# Data columns (total 40 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              552096 non-null  int64
#  1   created_at      552096 non-null  object
#  2   etp_id          552096 non-null  int64
#  3   method_name     552096 non-null  object
#  4   p_avans         550431 non-null  float64
#  5   avans_day       552094 non-null  float64
#  6   beneficiar      552091 non-null  object
#  7   contract_beg    552095 non-null  object
#  8   contract_dat    552095 non-null  object
#  9   contract_end    552096 non-null  object
#  10  contract_id     65487 non-null   float64
#  11  contract_num    552096 non-null  object
#  12  dvr             552096 non-null  int64
#  13  gen_id          3016 non-null    float64
#  14  inn             552096 non-null  int64
#  15  lot_date1       365252 non-null  object
#  16  lot_date2       365252 non-null  object
#  17  lot_id          552096 non-null  int64
#  18  ls              552096 non-null  object
#  19  maloy           552096 non-null  object
#  20  organ           552096 non-null  int64
#  21  pnfl            31553 non-null   float64
#  22  proc_id         552096 non-null  int64
#  23  purpose         552096 non-null  object
#  24  raschot         359099 non-null  float64
#  25  reestr_id       212740 non-null  float64
#  26  spok            552096 non-null  int64
#  27  sum_nds         254309 non-null  float64
#  28  p_summa         552096 non-null  int64
#  29  vendor_acc      552065 non-null  object
#  30  vendor_bank     551977 non-null  float64
#  31  vendor_country  3159 non-null    object
#  32  vendor_foreign  3159 non-null    object
#  33  vendor_info     3159 non-null    object
#  34  vendor_inn      551660 non-null  float64
#  35  vendor_kls      9323 non-null    object
#  36  vendor_name     552091 non-null  object
#  37  vendor_terr     545037 non-null  float64
#  38  version         67598 non-null   float64
#  39  request_id      552095 non-null  float64
# dtypes: float64(13), int64(9), object(18)
# memory usage: 168.5+ MB
#           id                  created_at  etp_id method_name       p_avans  \
# 0  134856344  2022-08-15 11:53:46.405213       1    RESULTAT  0.000000e+00
# 1  134856345  2022-08-15 11:53:46.423789       1    RESULTAT  5.856400e+08
# 2  134856346  2022-08-15 11:53:46.441535       1    RESULTAT  4.948725e+08
# 3  134856347  2022-08-15 11:53:46.455026       1    RESULTAT  4.237913e+09
# 4  134856348  2022-08-15 11:53:46.470510       1    RESULTAT  3.499965e+09
# 5  134856349  2022-08-15 11:53:46.486985       1    RESULTAT  0.000000e+00
# 6  134856350  2022-08-15 11:53:46.507769       1    RESULTAT  0.000000e+00
# 7  134856351  2022-08-15 11:53:46.521001       1    RESULTAT  0.000000e+00
# 8  134856352  2022-08-15 11:53:46.536308       1    RESULTAT  0.000000e+00
# 9  134856353  2022-08-15 11:53:46.551062       1    RESULTAT  0.000000e+00
#
#    avans_day beneficiar                contract_beg  \
# 0        0.0          -  2022-02-13 05:00:00.000000
# 1       10.0          -  2022-04-05 05:00:00.000000
# 2       10.0          -  2022-07-27 05:00:00.000000
# 3       25.0          -  2022-01-01 05:00:00.000000
# 4       30.0          -  2022-05-20 05:00:00.000000
# 5        0.0          -  2022-04-23 05:00:00.000000
# 6        0.0          -  2022-02-11 05:00:00.000000
# 7        0.0          -  2022-07-02 05:00:00.000000
# 8        0.0          -  2022-06-27 05:00:00.000000
# 9        5.0          -  2022-04-15 05:00:00.000000
#
#                  contract_dat                contract_end  ...  vendor_bank  \
# 0  2022-02-13 05:00:00.000000  2022-12-31 05:00:00.000000  ...       1064.0
# 1  2022-08-08 05:00:00.000000  2022-12-31 05:00:00.000000  ...        440.0
# 2  2022-08-11 05:00:00.000000  2022-12-31 05:00:00.000000  ...       1067.0
# 3  2022-08-15 05:00:00.000000  2022-12-31 05:00:00.000000  ...         22.0
# 4  2022-08-08 05:00:00.000000  2022-12-31 05:00:00.000000  ...        440.0
# 5  2022-04-23 05:00:00.000000  2022-12-31 05:00:00.000000  ...        395.0
# 6  2022-02-11 05:00:00.000000  2022-12-31 05:00:00.000000  ...       1188.0
# 7  2022-07-02 05:00:00.000000  2022-12-31 05:00:00.000000  ...         14.0
# 8  2022-06-27 05:00:00.000000  2022-12-31 05:00:00.000000  ...       1020.0
# 9  2022-08-12 05:00:00.000000  2022-12-31 05:00:00.000000  ...        855.0
#
#   vendor_country  vendor_foreign  vendor_info   vendor_inn vendor_kls  \
# 0            NaN             NaN          NaN  301004214.0        NaN
# 1            NaN             NaN          NaN  200230792.0        NaN
# 2            NaN             NaN          NaN  308763034.0        NaN
# 3            NaN             NaN          NaN  201214264.0        NaN
# 4            NaN             NaN          NaN  200666494.0        NaN
# 5            NaN             NaN          NaN  304815209.0        NaN
# 6            NaN             NaN          NaN  201127325.0        NaN
# 7            NaN             NaN          NaN  201901755.0        NaN
# 8            NaN             NaN          NaN  303119773.0        NaN
# 9            NaN             NaN          NaN  200324414.0        NaN
#
#                                          vendor_name  vendor_terr version  \
# 0                             ADA SERVIS NAVOIY  МЧЖ      12401.0   274.0
# 1                                    Андижон ХЭТК АЖ          0.0    29.0
# 2   MEGA FOOD TAMINOT MAS`ULIYATI CHEKLANGAN JAMIYAT      26266.0    23.0
# 3        Управление охраны УВД Самаркандской области          0.0    22.0
# 4                                  Кашкадарё ХЭТК АЖ          0.0    21.0
# 5                             ООО SHERZOD STATIONERY      18401.0    24.0
# 6                               OOO NASOS TA'MIRLASH       6219.0   268.0
# 7  URGANCH TUMAN SANITARIYA-EPIDEMIOLOGIK OSOYISH...      33217.0   102.0
# 8                                Otash Invest Servis      33401.0    42.0
# 9     СИРДАРЁ ХУДУДИЙ ЭЛЕКТР ТАРМОКЛАРИ КОРХОНАСИ АЖ      24231.0    21.0
#
#   request_id
# 0  2628573.0
# 1  2628574.0
# 2  2628575.0
# 3  2628576.0
# 4  2628577.0
# 5  2628578.0
# 6  2628579.0
# 7  2628580.0
# 8  2628581.0
# 9  2628582.0
#
# [10 rows x 40 columns]

# %%
#replace all missing values in vendor_terr with 1111
resultat['vendor_terr'].fillna(1111, inplace=True)

# %%
resultat.vendor_terr = resultat.vendor_terr.astype('int64')

# %%
rel_db = pd.read_csv('data/resultat_method_specifications.csv', sep=',')
rel_db.info()
rel_db.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1331501 entries, 0 to 1331500
# Data columns (total 2 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   resultat_method_id  1331501 non-null  int64
#  1   specifications_id   1331501 non-null  int64
# dtypes: int64(2)
# memory usage: 20.3 MB
#    resultat_method_id  specifications_id
# 0           135099322          136148211
# 1           135099323          136148212
# 2           135099324          136148213
# 3           135099325          136148214
# 4           135099326          136148215
# 5           135099327          136148216
# 6           135099328          136148217
# 7           135099329          136148218
# 8           135099330          136148219
# 9           135099331          136148220

# %%
#join resultat_method and rel_db on resultat.id and rel_db.resultat_method_id
resultat = resultat.merge(rel_db, left_on='id', right_on='resultat_method_id')
resultat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1331501 entries, 0 to 1331500
# Data columns (total 42 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   id                  1331501 non-null  int64
#  1   created_at          1331501 non-null  object
#  2   etp_id              1331501 non-null  int64
#  3   method_name         1331501 non-null  object
#  4   p_avans             1329103 non-null  float64
#  5   avans_day           1331499 non-null  float64
#  6   beneficiar          1331496 non-null  object
#  7   contract_beg        1331500 non-null  object
#  8   contract_dat        1331500 non-null  object
#  9   contract_end        1331501 non-null  object
#  10  contract_id         299532 non-null   float64
#  11  contract_num        1331501 non-null  object
#  12  dvr                 1331501 non-null  int64
#  13  gen_id              10588 non-null    float64
#  14  inn                 1331501 non-null  int64
#  15  lot_date1           471536 non-null   object
#  16  lot_date2           471536 non-null   object
#  17  lot_id              1331501 non-null  int64
#  18  ls                  1331501 non-null  object
#  19  maloy               1331501 non-null  object
#  20  organ               1331501 non-null  int64
#  21  pnfl                37952 non-null    float64
#  22  proc_id             1331501 non-null  int64
#  23  purpose             1331501 non-null  object
#  24  raschot             456313 non-null   float64
#  25  reestr_id           894408 non-null   float64
#  26  spok                1331501 non-null  int64
#  27  sum_nds             987832 non-null   float64
#  28  p_summa             1331501 non-null  int64
#  29  vendor_acc          1331421 non-null  object
#  30  vendor_bank         1331051 non-null  float64
#  31  vendor_country      8234 non-null     object
#  32  vendor_foreign      8234 non-null     object
#  33  vendor_info         8234 non-null     object
#  34  vendor_inn          1330277 non-null  float64
#  35  vendor_kls          16376 non-null    object
#  36  vendor_name         1331496 non-null  object
#  37  vendor_terr         1331501 non-null  int64
#  38  version             301650 non-null   float64
#  39  request_id          1331499 non-null  float64
#  40  resultat_method_id  1331501 non-null  int64
#  41  specifications_id   1331501 non-null  int64
# dtypes: float64(12), int64(12), object(18)
# memory usage: 436.8+ MB

# %%
specs = pd.read_csv('data/specifications.csv', sep=',')
specs.info()
specs.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2316791 entries, 0 to 2316790
# Data columns (total 12 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   id            int64
#  1   expense       float64
#  2   fin_year      float64
#  3   kls           object
#  4   npos          int64
#  5   tovar         object
#  6   tovar_amount  int64
#  7   tovar_edizm   object
#  8   tovar_name    object
#  9   tovar_note    object
#  10  tovar_price   int64
#  11  tovar_summa   int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 212.1+ MB
#           id     expense  fin_year  kls  npos               tovar  \
# 0  136854677  44252410.0       NaN  NaN     1  21.20.15.180-00037
# 1  136854678  44252410.0       NaN  NaN     1  21.20.12.150-00003
# 2  136854679  44821190.0       NaN  NaN     1  93.29.29.000-00002
# 3  136854680  44252110.0       NaN  NaN     1  25.71.14.110-00009
# 4  136854681  44252120.0       NaN  NaN     1  17.12.14.129-00002
# 5  136854682  44354990.0       NaN  NaN     1  21.31.12.300-00001
# 6  136854683  44299990.0       NaN  NaN     1  62.03.12.130-00003
# 7  136854684  44299990.0       NaN  NaN     1  62.03.12.130-00003
# 8  136854685  44252110.0       NaN  NaN     1  20.30.21.130-00003
# 9  136854686  44252110.0       NaN  NaN     1  82.19.11.000-00001
#
#    tovar_amount tovar_edizm  \
# 0           800           0
# 1           200           0
# 2             1          25
# 3             1           1
# 4           282           2
# 5             1          26
# 6             1          25
# 7             1          25
# 8            10           1
# 9           160           1
#
#                                           tovar_name tovar_note  tovar_price  \
# 0                           Анальгин 50% амп 2мл №10        NaN       720000
# 1                         Пирацетам 20% амп  5мл №10        NaN       800000
# 2     Услуги по организации и проведению мероприятий        NaN   1189000000
# 3       Набор столовых приборов из нержавеющей стали        NaN   8900000000
# 4                   Бумага для офисной техники белая        NaN      4456522
# 5                                 Электрокардиографы        NaN   1728695652
# 6  Услуга по техническому обслуживанию, сопровожд...        NaN   1099900000
# 7  Услуга по техническому обслуживанию, сопровожд...        NaN   1099900000
# 8                                       Краска эмаль        NaN      8434783
# 9                 Услуга по тиражированию документов        NaN      2173478
#
#    tovar_summa
# 0    576000000
# 1    160000000
# 2   1189000000
# 3   8900000000
# 4   1445250000
# 5   1988000000
# 6   1099900000
# 7   1099900000
# 8     97000000
# 9    399920000

# %%
#join resultat and specifications on resultat.specification_id and specifications.id
resultat = resultat.merge(specs, left_on='specifications_id', right_on='id')
resultat.info()
resultat.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1331501 entries, 0 to 1331500
# Data columns (total 54 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   id_x                1331501 non-null  int64
#  1   created_at          1331501 non-null  object
#  2   etp_id              1331501 non-null  int64
#  3   method_name         1331501 non-null  object
#  4   p_avans             1329103 non-null  float64
#  5   avans_day           1331499 non-null  float64
#  6   beneficiar          1331496 non-null  object
#  7   contract_beg        1331500 non-null  object
#  8   contract_dat        1331500 non-null  object
#  9   contract_end        1331501 non-null  object
#  10  contract_id         299532 non-null   float64
#  11  contract_num        1331501 non-null  object
#  12  dvr                 1331501 non-null  int64
#  13  gen_id              10588 non-null    float64
#  14  inn                 1331501 non-null  int64
#  15  lot_date1           471536 non-null   object
#  16  lot_date2           471536 non-null   object
#  17  lot_id              1331501 non-null  int64
#  18  ls                  1331501 non-null  object
#  19  maloy               1331501 non-null  object
#  20  organ               1331501 non-null  int64
#  21  pnfl                37952 non-null    float64
#  22  proc_id             1331501 non-null  int64
#  23  purpose             1331501 non-null  object
#  24  raschot             456313 non-null   float64
#  25  reestr_id           894408 non-null   float64
#  26  spok                1331501 non-null  int64
#  27  sum_nds             987832 non-null   float64
#  28  p_summa             1331501 non-null  int64
#  29  vendor_acc          1331421 non-null  object
#  30  vendor_bank         1331051 non-null  float64
#  31  vendor_country      8234 non-null     object
#  32  vendor_foreign      8234 non-null     object
#  33  vendor_info         8234 non-null     object
#  34  vendor_inn          1330277 non-null  float64
#  35  vendor_kls          16376 non-null    object
#  36  vendor_name         1331496 non-null  object
#  37  vendor_terr         1331501 non-null  int64
#  38  version             301650 non-null   float64
#  39  request_id          1331499 non-null  float64
#  40  resultat_method_id  1331501 non-null  int64
#  41  specifications_id   1331501 non-null  int64
#  42  id_y                1331501 non-null  int64
#  43  expense             1331501 non-null  float64
#  44  fin_year            1331501 non-null  float64
#  45  kls                 1331501 non-null  object
#  46  npos                1331501 non-null  int64
#  47  tovar               1331501 non-null  object
#  48  tovar_amount        1331501 non-null  int64
#  49  tovar_edizm         1329400 non-null  object
#  50  tovar_name          1331345 non-null  object
#  51  tovar_note          15333 non-null    object
#  52  tovar_price         1331501 non-null  int64
#  53  tovar_summa         1331501 non-null  int64
# dtypes: float64(14), int64(17), object(23)
# memory usage: 558.7+ MB
#         id_x                  created_at  etp_id method_name      p_avans  \
# 0  134856344  2022-08-15 11:53:46.405213       1    RESULTAT          0.0
# 1  134856345  2022-08-15 11:53:46.423789       1    RESULTAT  585640000.0
# 2  134856345  2022-08-15 11:53:46.423789       1    RESULTAT  585640000.0
# 3  134856345  2022-08-15 11:53:46.423789       1    RESULTAT  585640000.0
# 4  134856345  2022-08-15 11:53:46.423789       1    RESULTAT  585640000.0
# 5  134856345  2022-08-15 11:53:46.423789       1    RESULTAT  585640000.0
# 6  134856345  2022-08-15 11:53:46.423789       1    RESULTAT  585640000.0
# 7  134856345  2022-08-15 11:53:46.423789       1    RESULTAT  585640000.0
# 8  134856345  2022-08-15 11:53:46.423789       1    RESULTAT  585640000.0
# 9  134856345  2022-08-15 11:53:46.423789       1    RESULTAT  585640000.0
#
#    avans_day beneficiar                contract_beg  \
# 0        0.0          -  2022-02-13 05:00:00.000000
# 1       10.0          -  2022-04-05 05:00:00.000000
# 2       10.0          -  2022-04-05 05:00:00.000000
# 3       10.0          -  2022-04-05 05:00:00.000000
# 4       10.0          -  2022-04-05 05:00:00.000000
# 5       10.0          -  2022-04-05 05:00:00.000000
# 6       10.0          -  2022-04-05 05:00:00.000000
# 7       10.0          -  2022-04-05 05:00:00.000000
# 8       10.0          -  2022-04-05 05:00:00.000000
# 9       10.0          -  2022-04-05 05:00:00.000000
#
#                  contract_dat                contract_end  ...  fin_year  \
# 0  2022-02-13 05:00:00.000000  2022-12-31 05:00:00.000000  ...    2022.0
# 1  2022-08-08 05:00:00.000000  2022-12-31 05:00:00.000000  ...    2022.0
# 2  2022-08-08 05:00:00.000000  2022-12-31 05:00:00.000000  ...    2022.0
# 3  2022-08-08 05:00:00.000000  2022-12-31 05:00:00.000000  ...    2022.0
# 4  2022-08-08 05:00:00.000000  2022-12-31 05:00:00.000000  ...    2022.0
# 5  2022-08-08 05:00:00.000000  2022-12-31 05:00:00.000000  ...    2022.0
# 6  2022-08-08 05:00:00.000000  2022-12-31 05:00:00.000000  ...    2022.0
# 7  2022-08-08 05:00:00.000000  2022-12-31 05:00:00.000000  ...    2022.0
# 8  2022-08-08 05:00:00.000000  2022-12-31 05:00:00.000000  ...    2022.0
# 9  2022-08-08 05:00:00.000000  2022-12-31 05:00:00.000000  ...    2022.0
#
#                            kls  npos               tovar  tovar_amount  \
# 0  400910860124017094100079001     1  32.99.56.140-00002            14
# 1  100022860032207042133250001     1  35.12.10.110-00001           888
# 2  100022860032207042133250001     2  35.12.10.110-00001           888
# 3  100022860032207042133250001     3  35.12.10.110-00001           888
# 4  100022860032207042133250001     4  35.12.10.110-00001          1440
# 5  100022860032207042133250001     5  35.12.10.110-00001           876
# 6  100022860032207042133250001     6  35.12.10.110-00001           876
# 7  100022860032207042133250001     7  35.12.10.110-00001           876
# 8  100022860032207042133250001     8  35.12.10.110-00001           876
# 9  100022860032207042133250001     9  35.12.10.110-00001           878
#
#   tovar_edizm                         tovar_name  tovar_note tovar_price  \
# 0           0                    Настенное панно         NaN   120000000
# 1           1  Услуги по передаче электроэнергии         NaN       45000
# 2           1  Услуги по передаче электроэнергии         NaN       45000
# 3           1  Услуги по передаче электроэнергии         NaN       45000
# 4           1  Услуги по передаче электроэнергии         NaN       80000
# 5           1  Услуги по передаче электроэнергии         NaN       80000
# 6           1  Услуги по передаче электроэнергии         NaN       80000
# 7           1  Услуги по передаче электроэнергии         NaN       80000
# 8           1  Услуги по передаче электроэнергии         NaN       80000
# 9           1  Услуги по передаче электроэнергии         NaN       80000
#
#   tovar_summa
# 0  1680000000
# 1    39960000
# 2    39960000
# 3    39960000
# 4   115200000
# 5    70080000
# 6    70080000
# 7    70080000
# 8    70080000
# 9    70240000
#
# [10 rows x 54 columns]

# %%
resultat = resultat.drop(['id_x', 'id_y', 'specifications_id',  'resultat_method_id'], axis=1)

# %%
#only keep rows where proc_id = 6
resultat = resultat[resultat['proc_id'] == 6]
resultat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 293164 entries, 0 to 1331489
# Data columns (total 50 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   created_at      293164 non-null  object
#  1   etp_id          293164 non-null  int64
#  2   method_name     293164 non-null  object
#  3   p_avans         293164 non-null  float64
#  4   avans_day       293164 non-null  float64
#  5   beneficiar      293159 non-null  object
#  6   contract_beg    293164 non-null  object
#  7   contract_dat    293164 non-null  object
#  8   contract_end    293164 non-null  object
#  9   contract_id     22734 non-null   float64
#  10  contract_num    293164 non-null  object
#  11  dvr             293164 non-null  int64
#  12  gen_id          0 non-null       float64
#  13  inn             293164 non-null  int64
#  14  lot_date1       293164 non-null  object
#  15  lot_date2       293164 non-null  object
#  16  lot_id          293164 non-null  int64
#  17  ls              293164 non-null  object
#  18  maloy           293164 non-null  object
#  19  organ           293164 non-null  int64
#  20  pnfl            27496 non-null   float64
#  21  proc_id         293164 non-null  int64
#  22  purpose         293164 non-null  object
#  23  raschot         293164 non-null  float64
#  24  reestr_id       22727 non-null   float64
#  25  spok            293164 non-null  int64
#  26  sum_nds         24839 non-null   float64
#  27  p_summa         293164 non-null  int64
#  28  vendor_acc      293164 non-null  object
#  29  vendor_bank     293164 non-null  float64
#  30  vendor_country  0 non-null       object
#  31  vendor_foreign  0 non-null       object
#  32  vendor_info     0 non-null       object
#  33  vendor_inn      293164 non-null  float64
#  34  vendor_kls      2468 non-null    object
#  35  vendor_name     293159 non-null  object
#  36  vendor_terr     293164 non-null  int64
#  37  version         24828 non-null   float64
#  38  request_id      293164 non-null  float64
#  39  expense         293164 non-null  float64
#  40  fin_year        293164 non-null  float64
#  41  kls             293164 non-null  object
#  42  npos            293164 non-null  int64
#  43  tovar           293164 non-null  object
#  44  tovar_amount    293164 non-null  int64
#  45  tovar_edizm     291063 non-null  object
#  46  tovar_name      293008 non-null  object
#  47  tovar_note      11 non-null      object
#  48  tovar_price     293164 non-null  int64
#  49  tovar_summa     293164 non-null  int64
# dtypes: float64(14), int64(13), object(23)
# memory usage: 114.1+ MB

# %%
contract = pd.read_csv('data/contract_info.csv', sep=',')
contract.info()
contract.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371429 entries, 0 to 371428
# Data columns (total 20 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            371429 non-null  int64
#  1   created_at    371429 non-null  object
#  2   method_name   371429 non-null  object
#  3   acc           371429 non-null  object
#  4   action_name   304371 non-null  object
#  5   contract_num  371428 non-null  object
#  6   errmsg        93790 non-null   object
#  7   gen_id        371429 non-null  int64
#  8   inn           371429 non-null  int64
#  9   kls           2272 non-null    object
#  10  lot_id        371429 non-null  int64
#  11  ls            371429 non-null  object
#  12  mfo           371429 non-null  int64
#  13  pay_id        371429 non-null  int64
#  14  reg_dat       371429 non-null  object
#  15  state         371429 non-null  int64
#  16  summa         371429 non-null  int64
#  17  version       371429 non-null  int64
#  18  request_id    371429 non-null  int64
#  19  response_id   371429 non-null  int64
# dtypes: int64(11), object(9)
# memory usage: 56.7+ MB
#     id                  created_at    method_name                   acc  \
# 0  486  2022-07-29 10:10:04.045153  CONTRACT_INFO  20208000000823784001
# 1  487  2022-07-29 10:10:06.775718  CONTRACT_INFO  20208000400608809001
# 2  488  2022-07-29 10:10:07.034562  CONTRACT_INFO  20208000905487588001
# 3  489  2022-07-29 10:10:12.263716  CONTRACT_INFO  20208000905487588001
# 4  490  2022-07-29 10:10:15.021260  CONTRACT_INFO  20208000905487588001
# 5  491  2022-07-29 10:10:20.269586  CONTRACT_INFO  20208000905487588001
# 6  492  2022-07-29 10:10:25.436582  CONTRACT_INFO  20208000800809354003
# 7  493  2022-07-29 10:10:28.155899  CONTRACT_INFO  20208000501809160001
# 8  494  2022-07-29 10:10:35.122731  CONTRACT_INFO  20208000900334434001
# 9  495  2022-07-29 10:10:35.372409  CONTRACT_INFO  20208000805010007001
#
#     action_name     contract_num  \
# 0           NaN               84
# 1           NaN            УН-10
# 2     Утвердить            Х-234
# 3     Утвердить            Х-236
# 4     Утвердить            Х-235
# 5     Утвердить            Х-233
# 6     Утвердить  11114-2020/IJRO
# 7           NaN               76
# 8  Аннулировать           493490
# 9  Аннулировать            15413
#
#                                               errmsg  gen_id        inn  kls  \
# 0                             11;шакар нархи киммат;       0  305128555  NaN
# 1                                   11;максади хато;       0  303801306  NaN
# 2                                                NaN       0  309245724  NaN
# 3                                                NaN       0  309245724  NaN
# 4                                                NaN       0  309245724  NaN
# 5                                                NaN       0  309245724  NaN
# 6                                                NaN       0  305109680  NaN
# 7  11;юрист кайси ташкилотники эканлиги тулдирилм...       0  202269916  NaN
# 8                 Отменен казначейством. Сотрудник 0       0  200861450  NaN
# 9                 Отменен казначейством. Сотрудник 0       0  302443910  NaN
#
#            lot_id                           ls   mfo    pay_id  \
# 0  22110047725633  100021860064017073201054004    87         0
# 1  22110036725803  100021860144017042402170006   231         0
# 2  22110038722554  100022860332367072120054005  1017  30183939
# 3  22110038722381  100022860332367072120054005  1017  30183940
# 4  22110038721737  100022860332367072130054020  1017  30183941
# 5  22110038721539  100022860332367072130054020  1017  30183943
# 6  22110010723984  401022860332047109120141001  1018  30185454
# 7  22110014725388  100022860222107011903340001   845         0
# 8  22111008571217  401022860122117109120141001    84  30176241
# 9  22111007016576  401410860144017033232011002   115  29173996
#
#                       reg_dat  state       summa  version  request_id  \
# 0  2022-07-29 05:00:00.000000      3   305000000        0     2424080
# 1  2022-07-29 05:00:00.000000      3   950000000        0     2425252
# 2  2022-07-28 05:00:00.000000      2  1415768400        0     2415485
# 3  2022-07-28 05:00:00.000000      2   344107600        0     2414986
# 4  2022-07-28 05:00:00.000000      2   207073600        0     2412375
# 5  2022-07-28 05:00:00.000000      2   947566000        0     2411802
# 6  2022-07-29 05:00:00.000000      2    60712500        0     2418348
# 7  2022-07-29 05:00:00.000000      3   180000000        0     2422458
# 8  2022-07-28 05:00:00.000000      5    10760000        0     2407881
# 9  2022-02-22 05:00:00.000000      5  1393080000        0      595379
#
#    response_id
# 0      4035226
# 1      4035227
# 2      4035228
# 3      4035229
# 4      4035230
# 5      4035231
# 6      4035232
# 7      4035233
# 8      4035241
# 9      4035242

# %%
#drop duplicates response_id keep last
contract.drop_duplicates(subset='response_id', keep='last', inplace=True)

# %%
contract = contract[contract.state == 2]

# %%
contract = contract.drop_duplicates('lot_id')

# %%
contract.request_id.head()
# Out:
# 2    2415485
# 3    2414986
# 4    2412375
# 5    2411802
# 6    2418348
# Name: request_id, dtype: int64

# %%
contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 267386 entries, 2 to 371428
# Data columns (total 20 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            267386 non-null  int64
#  1   created_at    267386 non-null  object
#  2   method_name   267386 non-null  object
#  3   acc           267386 non-null  object
#  4   action_name   267367 non-null  object
#  5   contract_num  267386 non-null  object
#  6   errmsg        0 non-null       object
#  7   gen_id        267386 non-null  int64
#  8   inn           267386 non-null  int64
#  9   kls           0 non-null       object
#  10  lot_id        267386 non-null  int64
#  11  ls            267386 non-null  object
#  12  mfo           267386 non-null  int64
#  13  pay_id        267386 non-null  int64
#  14  reg_dat       267386 non-null  object
#  15  state         267386 non-null  int64
#  16  summa         267386 non-null  int64
#  17  version       267386 non-null  int64
#  18  request_id    267386 non-null  int64
#  19  response_id   267386 non-null  int64
# dtypes: int64(11), object(9)
# memory usage: 42.8+ MB

# %%
resultat = resultat[resultat.proc_id == 6]

# %%
#is lot_id in contract same as lot_id in resultat
resultat['lot_id'].isin(contract['lot_id']).value_counts()
# Out:
# True     196815
# False     96349
# Name: lot_id, dtype: int64

# %%
#only keep rows where lot_id is in contract
resultat = resultat[resultat['lot_id'].isin(contract['lot_id'])]

# %%
resultat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 196815 entries, 0 to 1331489
# Data columns (total 50 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   created_at      196815 non-null  object
#  1   etp_id          196815 non-null  int64
#  2   method_name     196815 non-null  object
#  3   p_avans         196815 non-null  float64
#  4   avans_day       196815 non-null  float64
#  5   beneficiar      196810 non-null  object
#  6   contract_beg    196815 non-null  object
#  7   contract_dat    196815 non-null  object
#  8   contract_end    196815 non-null  object
#  9   contract_id     21368 non-null   float64
#  10  contract_num    196815 non-null  object
#  11  dvr             196815 non-null  int64
#  12  gen_id          0 non-null       float64
#  13  inn             196815 non-null  int64
#  14  lot_date1       196815 non-null  object
#  15  lot_date2       196815 non-null  object
#  16  lot_id          196815 non-null  int64
#  17  ls              196815 non-null  object
#  18  maloy           196815 non-null  object
#  19  organ           196815 non-null  int64
#  20  pnfl            18810 non-null   float64
#  21  proc_id         196815 non-null  int64
#  22  purpose         196815 non-null  object
#  23  raschot         196815 non-null  float64
#  24  reestr_id       21361 non-null   float64
#  25  spok            196815 non-null  int64
#  26  sum_nds         23388 non-null   float64
#  27  p_summa         196815 non-null  int64
#  28  vendor_acc      196815 non-null  object
#  29  vendor_bank     196815 non-null  float64
#  30  vendor_country  0 non-null       object
#  31  vendor_foreign  0 non-null       object
#  32  vendor_info     0 non-null       object
#  33  vendor_inn      196815 non-null  float64
#  34  vendor_kls      2088 non-null    object
#  35  vendor_name     196810 non-null  object
#  36  vendor_terr     196815 non-null  int64
#  37  version         23377 non-null   float64
#  38  request_id      196815 non-null  float64
#  39  expense         196815 non-null  float64
#  40  fin_year        196815 non-null  float64
#  41  kls             196815 non-null  object
#  42  npos            196815 non-null  int64
#  43  tovar           196815 non-null  object
#  44  tovar_amount    196815 non-null  int64
#  45  tovar_edizm     194799 non-null  object
#  46  tovar_name      196815 non-null  object
#  47  tovar_note      11 non-null      object
#  48  tovar_price     196815 non-null  int64
#  49  tovar_summa     196815 non-null  int64
# dtypes: float64(14), int64(13), object(23)
# memory usage: 76.6+ MB

# %%
df = pd.merge(resultat, contract, on='lot_id', how='left')

# %%
df.info()
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 196815 entries, 0 to 196814
# Data columns (total 69 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   created_at_x    196815 non-null  object
#  1   etp_id          196815 non-null  int64
#  2   method_name_x   196815 non-null  object
#  3   p_avans         196815 non-null  float64
#  4   avans_day       196815 non-null  float64
#  5   beneficiar      196810 non-null  object
#  6   contract_beg    196815 non-null  object
#  7   contract_dat    196815 non-null  object
#  8   contract_end    196815 non-null  object
#  9   contract_id     21368 non-null   float64
#  10  contract_num_x  196815 non-null  object
#  11  dvr             196815 non-null  int64
#  12  gen_id_x        0 non-null       float64
#  13  inn_x           196815 non-null  int64
#  14  lot_date1       196815 non-null  object
#  15  lot_date2       196815 non-null  object
#  16  lot_id          196815 non-null  int64
#  17  ls_x            196815 non-null  object
#  18  maloy           196815 non-null  object
#  19  organ           196815 non-null  int64
#  20  pnfl            18810 non-null   float64
#  21  proc_id         196815 non-null  int64
#  22  purpose         196815 non-null  object
#  23  raschot         196815 non-null  float64
#  24  reestr_id       21361 non-null   float64
#  25  spok            196815 non-null  int64
#  26  sum_nds         23388 non-null   float64
#  27  p_summa         196815 non-null  int64
#  28  vendor_acc      196815 non-null  object
#  29  vendor_bank     196815 non-null  float64
#  30  vendor_country  0 non-null       object
#  31  vendor_foreign  0 non-null       object
#  32  vendor_info     0 non-null       object
#  33  vendor_inn      196815 non-null  float64
#  34  vendor_kls      2088 non-null    object
#  35  vendor_name     196810 non-null  object
#  36  vendor_terr     196815 non-null  int64
#  37  version_x       23377 non-null   float64
#  38  request_id_x    196815 non-null  float64
#  39  expense         196815 non-null  float64
#  40  fin_year        196815 non-null  float64
#  41  kls_x           196815 non-null  object
#  42  npos            196815 non-null  int64
#  43  tovar           196815 non-null  object
#  44  tovar_amount    196815 non-null  int64
#  45  tovar_edizm     194799 non-null  object
#  46  tovar_name      196815 non-null  object
#  47  tovar_note      11 non-null      object
#  48  tovar_price     196815 non-null  int64
#  49  tovar_summa     196815 non-null  int64
#  50  id              196815 non-null  int64
#  51  created_at_y    196815 non-null  object
#  52  method_name_y   196815 non-null  object
#  53  acc             196815 non-null  object
#  54  action_name     196815 non-null  object
#  55  contract_num_y  196815 non-null  object
#  56  errmsg          0 non-null       object
#  57  gen_id_y        196815 non-null  int64
#  58  inn_y           196815 non-null  int64
#  59  kls_y           0 non-null       object
#  60  ls_y            196815 non-null  object
#  61  mfo             196815 non-null  int64
#  62  pay_id          196815 non-null  int64
#  63  reg_dat         196815 non-null  object
#  64  state           196815 non-null  int64
#  65  summa           196815 non-null  int64
#  66  version_y       196815 non-null  int64
#  67  request_id_y    196815 non-null  int64
#  68  response_id     196815 non-null  int64
# dtypes: float64(14), int64(23), object(32)
# memory usage: 105.1+ MB
#                  created_at_x  etp_id method_name_x  p_avans  avans_day  \
# 0  2022-08-15 11:53:46.405213       1      RESULTAT      0.0        0.0
# 1  2022-08-15 11:53:46.486985       1      RESULTAT      0.0        0.0
# 2  2022-08-15 11:53:46.507769       1      RESULTAT      0.0        0.0
# 3  2022-08-15 11:53:46.521001       1      RESULTAT      0.0        0.0
# 4  2022-08-15 11:53:46.536308       1      RESULTAT      0.0        0.0
# 5  2022-08-15 11:53:46.570803       1      RESULTAT      0.0        0.0
# 6  2022-08-15 11:53:46.590040       1      RESULTAT      0.0        0.0
# 7  2022-08-15 11:53:46.602773       1      RESULTAT      0.0        0.0
# 8  2022-08-15 11:53:46.614504       1      RESULTAT      0.0        0.0
# 9  2022-08-15 11:53:46.623979       1      RESULTAT      0.0        0.0
#
#   beneficiar                contract_beg                contract_dat  \
# 0          -  2022-02-13 05:00:00.000000  2022-02-13 05:00:00.000000
# 1          -  2022-04-23 05:00:00.000000  2022-04-23 05:00:00.000000
# 2          -  2022-02-11 05:00:00.000000  2022-02-11 05:00:00.000000
# 3          -  2022-07-02 05:00:00.000000  2022-07-02 05:00:00.000000
# 4          -  2022-06-27 05:00:00.000000  2022-06-27 05:00:00.000000
# 5          -  2022-02-11 05:00:00.000000  2022-02-11 05:00:00.000000
# 6          -  2022-07-25 05:00:00.000000  2022-07-25 05:00:00.000000
# 7          -  2022-05-19 05:00:00.000000  2022-05-19 05:00:00.000000
# 8          -  2022-04-23 05:00:00.000000  2022-04-23 05:00:00.000000
# 9          -  2022-08-07 05:00:00.000000  2022-08-07 05:00:00.000000
#
#                  contract_end  contract_id  ... kls_y  \
# 0  2022-12-31 05:00:00.000000   29133486.0  ...   NaN
# 1  2022-12-31 05:00:00.000000   29555607.0  ...   NaN
# 2  2022-12-31 05:00:00.000000   29127493.0  ...   NaN
# 3  2022-12-31 05:00:00.000000   30036958.0  ...   NaN
# 4  2022-12-31 05:00:00.000000   29994262.0  ...   NaN
# 5  2022-12-31 05:00:00.000000   29127526.0  ...   NaN
# 6  2022-12-31 05:00:00.000000   30148540.0  ...   NaN
# 7  2022-12-31 05:00:00.000000   29721303.0  ...   NaN
# 8  2022-12-31 05:00:00.000000   29555607.0  ...   NaN
# 9  2022-12-31 05:00:00.000000   30232291.0  ...   NaN
#
#                           ls_y   mfo    pay_id                     reg_dat  \
# 0  400910860124017094100079001  1064  29133486  2022-07-29 05:00:00.000000
# 1  400110860184017092500054001   395  29555607  2022-08-15 05:00:00.000000
# 2  100010860062047042402170002  1188  29127493  2022-07-29 05:00:00.000000
# 3  400322860332177073101054002    14  30036958  2022-08-01 05:00:00.000000
# 4  401421860334017073201054008  1020  29994262  2022-08-04 05:00:00.000000
# 5  100010860062047042402170002  1188  29127526  2022-08-01 05:00:00.000000
# 6  100010860262667073203054001    14  30148540  2022-07-29 05:00:00.000000
# 7  100010860262777092500044001   401  29721303  2022-08-01 05:00:00.000000
# 8  400110860184017092500054001   395  29555607  2022-08-15 05:00:00.000000
# 9  400321860144017073101054002    14  30232291  2022-08-08 05:00:00.000000
#
#   state       summa version_y request_id_y  response_id
# 0     2  1680000000       241      2431676      4052080
# 1     2    76965000        23      2628269      4369588
# 2     2  1330000000       235      2431681      4052086
# 3     2    15960000        70      2441103      4078203
# 4     2    50000000        21      2495920      4160304
# 5     2   980000000       236      2441068      4078168
# 6     2   750000000        22      2431683      4052088
# 7     2   150000000       148      2441106      4078206
# 8     2    76965000        23      2628269      4369588
# 9     2   551000000         0      2526340      4204240
#
# [10 rows x 69 columns]

# %%
#is request_id in contract same as request_id in resultat
df['request_id_x'].isin(df['request_id_y']).value_counts()
# Out:
# True     158960
# False     37855
# Name: request_id_x, dtype: int64

# %%
#keep only rows where request_id_x is in request_id_y
df = df[df['request_id_x'].isin(df['request_id_y'])]

# %%
df = df.drop('request_id_y', axis=1)

# %%
df['request_id'] = df['request_id_x']

# %%
#extract month from contract_dat and plot contract_num
df['contract_dat'] = pd.to_datetime(df['contract_dat'], errors='coerce')

# %%
df['contract_num'] = df['contract_num_x']
df = df.drop(['contract_num_x', 'contract_num_y'], axis=1)

# %%
df = df.drop(['version_x', 'version_y', 'errmsg', 'state', 'request_id_x', 'method_name_x', 'method_name_y', 'gen_id_x', 'gen_id_y', 'kls_x', 'kls_y'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158960 entries, 219 to 196725
# Data columns (total 57 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   created_at_x    158960 non-null  object
#  1   etp_id          158960 non-null  int64
#  2   p_avans         158960 non-null  float64
#  3   avans_day       158960 non-null  float64
#  4   beneficiar      158960 non-null  object
#  5   contract_beg    158960 non-null  object
#  6   contract_dat    158960 non-null  datetime64[ns]
#  7   contract_end    158960 non-null  object
#  8   contract_id     747 non-null     float64
#  9   dvr             158960 non-null  int64
#  10  inn_x           158960 non-null  int64
#  11  lot_date1       158960 non-null  object
#  12  lot_date2       158960 non-null  object
#  13  lot_id          158960 non-null  int64
#  14  ls_x            158960 non-null  object
#  15  maloy           158960 non-null  object
#  16  organ           158960 non-null  int64
#  17  pnfl            18120 non-null   float64
#  18  proc_id         158960 non-null  int64
#  19  purpose         158960 non-null  object
#  20  raschot         158960 non-null  float64
#  21  reestr_id       746 non-null     float64
#  22  spok            158960 non-null  int64
#  23  sum_nds         2675 non-null    float64
#  24  p_summa         158960 non-null  int64
#  25  vendor_acc      158960 non-null  object
#  26  vendor_bank     158960 non-null  float64
#  27  vendor_country  0 non-null       object
#  28  vendor_foreign  0 non-null       object
#  29  vendor_info     0 non-null       object
#  30  vendor_inn      158960 non-null  float64
#  31  vendor_kls      654 non-null     object
#  32  vendor_name     158960 non-null  object
#  33  vendor_terr     158960 non-null  int64
#  34  expense         158960 non-null  float64
#  35  fin_year        158960 non-null  float64
#  36  npos            158960 non-null  int64
#  37  tovar           158960 non-null  object
#  38  tovar_amount    158960 non-null  int64
#  39  tovar_edizm     157036 non-null  object
#  40  tovar_name      158960 non-null  object
#  41  tovar_note      5 non-null       object
#  42  tovar_price     158960 non-null  int64
#  43  tovar_summa     158960 non-null  int64
#  44  id              158960 non-null  int64
#  45  created_at_y    158960 non-null  object
#  46  acc             158960 non-null  object
#  47  action_name     158960 non-null  object
#  48  inn_y           158960 non-null  int64
#  49  ls_y            158960 non-null  object
#  50  mfo             158960 non-null  int64
#  51  pay_id          158960 non-null  int64
#  52  reg_dat         158960 non-null  object
#  53  summa           158960 non-null  int64
#  54  response_id     158960 non-null  int64
#  55  request_id      158960 non-null  float64
#  56  contract_num    158960 non-null  object
# dtypes: datetime64[ns](1), float64(12), int64(19), object(25)
# memory usage: 70.3+ MB

# %%
months = pd.to_datetime(df['contract_dat'], format='%m').dt.month_name(locale='ru_RU').str.slice(stop=3)

#plot contract_num by month
plt.figure(figsize=(10, 5))
sns.countplot(x=months, data=df.contract_num)
plt.xticks(rotation=90)
#show numbers on top of bars
for p in plt.gca().patches:
    plt.gca().annotate('{:.0f}'.format(p.get_height()), (p.get_x()+p.get_width()/2., p.get_height()), 
                       ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.title('Количество контрактов по месяцам')
# Out:
# Text(0.5, 1.0, 'Количество контрактов по месяцам')

# %% [markdown]
# <h2>Vendor_country (no country on electronic store)</h2>

# %%
#how many missing values are there in the dataset?
df.isnull().sum()
# Out:
# created_at_x           0
# etp_id                 0
# p_avans                0
# avans_day              0
# beneficiar             0
# contract_beg           0
# contract_dat           0
# contract_end           0
# contract_id       158213
# dvr                    0
# inn_x                  0
# lot_date1              0
# lot_date2              0
# lot_id                 0
# ls_x                   0
# maloy                  0
# organ                  0
# pnfl              140840
# proc_id                0
# purpose                0
# raschot                0
# reestr_id         158214
# spok                   0
# sum_nds           156285
# p_summa                0
# vendor_acc             0
# vendor_bank            0
# vendor_country    158960
# vendor_foreign    158960
# vendor_info       158960
# vendor_inn             0
# vendor_kls        158306
# vendor_name            0
# vendor_terr            0
# expense                0
# fin_year               0
# npos                   0
# tovar                  0
# tovar_amount           0
# tovar_edizm         1924
# tovar_name             0
# tovar_note        158955
# tovar_price            0
# tovar_summa            0
# id                     0
# created_at_y           0
# acc                    0
# action_name            0
# inn_y                  0
# ls_y                   0
# mfo                    0
# pay_id                 0
# reg_dat                0
# summa                  0
# response_id            0
# request_id             0
# contract_num           0
# dtype: int64

# %%
df.drop(['vendor_kls', 'vendor_country', 'vendor_info', 'vendor_foreign', 'reestr_id', 'pnfl', 'contract_id', 'sum_nds'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158960 entries, 219 to 196725
# Data columns (total 49 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   created_at_x  158960 non-null  object
#  1   etp_id        158960 non-null  int64
#  2   p_avans       158960 non-null  float64
#  3   avans_day     158960 non-null  float64
#  4   beneficiar    158960 non-null  object
#  5   contract_beg  158960 non-null  object
#  6   contract_dat  158960 non-null  datetime64[ns]
#  7   contract_end  158960 non-null  object
#  8   dvr           158960 non-null  int64
#  9   inn_x         158960 non-null  int64
#  10  lot_date1     158960 non-null  object
#  11  lot_date2     158960 non-null  object
#  12  lot_id        158960 non-null  int64
#  13  ls_x          158960 non-null  object
#  14  maloy         158960 non-null  object
#  15  organ         158960 non-null  int64
#  16  proc_id       158960 non-null  int64
#  17  purpose       158960 non-null  object
#  18  raschot       158960 non-null  float64
#  19  spok          158960 non-null  int64
#  20  p_summa       158960 non-null  int64
#  21  vendor_acc    158960 non-null  object
#  22  vendor_bank   158960 non-null  float64
#  23  vendor_inn    158960 non-null  float64
#  24  vendor_name   158960 non-null  object
#  25  vendor_terr   158960 non-null  int64
#  26  expense       158960 non-null  float64
#  27  fin_year      158960 non-null  float64
#  28  npos          158960 non-null  int64
#  29  tovar         158960 non-null  object
#  30  tovar_amount  158960 non-null  int64
#  31  tovar_edizm   157036 non-null  object
#  32  tovar_name    158960 non-null  object
#  33  tovar_note    5 non-null       object
#  34  tovar_price   158960 non-null  int64
#  35  tovar_summa   158960 non-null  int64
#  36  id            158960 non-null  int64
#  37  created_at_y  158960 non-null  object
#  38  acc           158960 non-null  object
#  39  action_name   158960 non-null  object
#  40  inn_y         158960 non-null  int64
#  41  ls_y          158960 non-null  object
#  42  mfo           158960 non-null  int64
#  43  pay_id        158960 non-null  int64
#  44  reg_dat       158960 non-null  object
#  45  summa         158960 non-null  int64
#  46  response_id   158960 non-null  int64
#  47  request_id    158960 non-null  float64
#  48  contract_num  158960 non-null  object
# dtypes: datetime64[ns](1), float64(8), int64(19), object(21)
# memory usage: 64.7+ MB

# %%
df.organ.value_counts().head()
# Out:
# 508000111      393
# 62481000002    358
# 1740           352
# 22807          342
# 62560000002    338
# Name: organ, dtype: int64

# %%
df.vendor_terr.value_counts().head()
# Out:
# 18401    8205
# 26266    6768
# 24401    6767
# 26294    6215
# 35401    6024
# Name: vendor_terr, dtype: int64

# %% [markdown]
# <h2>Adding other details</h2>

# %%
#data doesnt have column names so we need to add them as id and name
terr_names = pd.read_csv('data/vendor_terr_names.csv', sep=',\t', names=['id', 'name'])
terr_names.info()
terr_names.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3303 entries, 0 to 3302
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      3303 non-null   int64
#  1   name    3303 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 51.7+ KB
# /var/folders/fh/yq61fqcs3q9_0k81sxnf4ff40000gn/T/ipykernel_41564/1713777579.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   terr_names = pd.read_csv('data/vendor_terr_names.csv', sep=',\t', names=['id', 'name'])
#            id                                           name
# 0     1703200                 Andijon viloyatining tumanlari
# 1  1710237800  Kasbi tumanining qishloq fuqarolar yig‘inlari
# 2  1722210566                                    Paxtakurash
# 3     1703202                               Oltinko‘l tumani
# 4  1710237822                                        Qamashi
# 5  1722210568                                       Namozgoh
# 6  1703202550             Oltinko‘l tumanining shaharchalari
# 7  1710237825                                        Komilon
# 8  1722210572                                        Jamatak
# 9  1703202552                                        Bo‘ston

# %%
#does df vendor_terr only have 5 letter codes?
df['vendor_terr'].astype(str).apply(len).gt(3).sum()
# Out:
# 156021

# %%
#keep only rows where vendor_terr is in terr_names
terr_names = terr_names[terr_names['id'].isin(df['vendor_terr'])]

# %%
df.vendor_terr.value_counts().head()
# Out:
# 18401    8205
# 26266    6768
# 24401    6767
# 26294    6215
# 35401    6024
# Name: vendor_terr, dtype: int64

# %%
#filter all vendor_terr that starts with 17
df[df['vendor_terr'].astype(str).str.startswith('17')]
# Out:
# Empty DataFrame
# Columns: [created_at_x, etp_id, p_avans, avans_day, beneficiar, contract_beg, contract_dat, contract_end, dvr, inn_x, lot_date1, lot_date2, lot_id, ls_x, maloy, organ, proc_id, purpose, raschot, spok, p_summa, vendor_acc, vendor_bank, vendor_inn, vendor_name, vendor_terr, expense, fin_year, npos, tovar, tovar_amount, tovar_edizm, tovar_name, tovar_note, tovar_price, tovar_summa, id, created_at_y, acc, action_name, inn_y, ls_y, mfo, pay_id, reg_dat, summa, response_id, request_id, contract_num]
# Index: []
#
# [0 rows x 49 columns]

# %%
df.vendor_terr.nunique()
# Out:
# 219

# %%
df = df.drop(['created_at_x', 'created_at_y', 'beneficiar', 'contract_beg', 'contract_end', 'dvr', 'inn_x', 'inn_y', 'ls_x', 'ls_y', 'mfo'], axis=1)

# %%
df.info()
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158960 entries, 219 to 196725
# Data columns (total 38 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   etp_id        158960 non-null  int64
#  1   p_avans       158960 non-null  float64
#  2   avans_day     158960 non-null  float64
#  3   contract_dat  158960 non-null  datetime64[ns]
#  4   lot_date1     158960 non-null  object
#  5   lot_date2     158960 non-null  object
#  6   lot_id        158960 non-null  int64
#  7   maloy         158960 non-null  object
#  8   organ         158960 non-null  int64
#  9   proc_id       158960 non-null  int64
#  10  purpose       158960 non-null  object
#  11  raschot       158960 non-null  float64
#  12  spok          158960 non-null  int64
#  13  p_summa       158960 non-null  int64
#  14  vendor_acc    158960 non-null  object
#  15  vendor_bank   158960 non-null  float64
#  16  vendor_inn    158960 non-null  float64
#  17  vendor_name   158960 non-null  object
#  18  vendor_terr   158960 non-null  int64
#  19  expense       158960 non-null  float64
#  20  fin_year      158960 non-null  float64
#  21  npos          158960 non-null  int64
#  22  tovar         158960 non-null  object
#  23  tovar_amount  158960 non-null  int64
#  24  tovar_edizm   157036 non-null  object
#  25  tovar_name    158960 non-null  object
#  26  tovar_note    5 non-null       object
#  27  tovar_price   158960 non-null  int64
#  28  tovar_summa   158960 non-null  int64
#  29  id            158960 non-null  int64
#  30  acc           158960 non-null  object
#  31  action_name   158960 non-null  object
#  32  pay_id        158960 non-null  int64
#  33  reg_dat       158960 non-null  object
#  34  summa         158960 non-null  int64
#  35  response_id   158960 non-null  int64
#  36  request_id    158960 non-null  float64
#  37  contract_num  158960 non-null  object
# dtypes: datetime64[ns](1), float64(8), int64(15), object(14)
# memory usage: 51.3+ MB
#      etp_id  p_avans  avans_day        contract_dat  \
# 219       1      0.0        0.0 2022-08-15 05:00:00
# 220       1      0.0        0.0 2022-08-15 05:00:00
# 221       1      0.0        0.0 2022-08-15 05:00:00
# 222       1      0.0        0.0 2022-08-15 05:00:00
# 223       1      0.0        0.0 2022-08-15 05:00:00
# 224       1      0.0        0.0 2022-08-15 05:00:00
# 225       1      0.0        0.0 2022-08-15 05:00:00
# 226       1      0.0        0.0 2022-08-15 05:00:00
# 227       1      0.0        0.0 2022-08-15 05:00:00
# 228       1      0.0        0.0 2022-08-15 05:00:00
#
#                       lot_date1                   lot_date2          lot_id  \
# 219  2022-08-10 05:00:00.000000  2022-08-12 05:00:00.000000  22111008617860
# 220  2022-08-11 05:00:00.000000  2022-08-13 05:00:00.000000  22111008625670
# 221  2022-08-12 05:00:00.000000  2022-08-14 05:00:00.000000  22111008627539
# 222  2022-08-12 05:00:00.000000  2022-08-14 05:00:00.000000  22111008627544
# 223  2022-08-12 05:00:00.000000  2022-08-14 05:00:00.000000  22111008628182
# 224  2022-08-11 05:00:00.000000  2022-08-13 05:00:00.000000  22111008623226
# 225  2022-08-11 05:00:00.000000  2022-08-13 05:00:00.000000  22111008623230
# 226  2022-08-12 05:00:00.000000  2022-08-14 05:00:00.000000  22111008627589
# 227  2022-08-12 05:00:00.000000  2022-08-14 05:00:00.000000  22111008627578
# 228  2022-08-13 05:00:00.000000  2022-08-15 05:00:00.000000  22111008631393
#
#     maloy      organ  proc_id  ... tovar_summa     id                   acc  \
# 219     Y  507000003        6  ...  1380000000  67738  20208000005150641001
# 220     Y  560000638        6  ...  1000000020  67739  20208000604264509008
# 221     Y  673000051        6  ...    81386000  67741  20210000500314531001
# 222     Y        263        6  ...   282000000  67742  23402000300100001010
# 223     Y       1674        6  ...  2637600000  67761  20210000704995315002
# 224     Y       5598        6  ...   368300000  67770  20208000800627630001
# 225     Y        379        6  ...    16500000  67771  20208000905514644001
# 226     Y  481000269        6  ...   734800000  67772  20208000103898534001
# 227     Y  460000005        6  ...   132000000  67773  20208000604705569001
# 228     Y  568000040        6  ...    69000000  67783  20208000800687146002
#
#      action_name    pay_id                     reg_dat       summa  \
# 219    Утвердить  30277671  2022-08-15 05:00:00.000000  1380000000
# 220    Утвердить  30277672  2022-08-15 05:00:00.000000  1000000020
# 221    Утвердить  30277673  2022-08-15 05:00:00.000000    81386000
# 222    Утвердить  30277674  2022-08-15 05:00:00.000000   282000000
# 223    Утвердить  30277695  2022-08-15 05:00:00.000000  2637600000
# 224    Утвердить  30277702  2022-08-15 05:00:00.000000   368300000
# 225    Утвердить  30277703  2022-08-15 05:00:00.000000    16500000
# 226    Утвердить  30277704  2022-08-15 05:00:00.000000   734800000
# 227    Утвердить  30277705  2022-08-15 05:00:00.000000   132000000
# 228    Утвердить  30277719  2022-08-15 05:00:00.000000    69000000
#
#     response_id  request_id  contract_num
# 219     4370278   2628882.0        546508
# 220     4370286   2628886.0        546507
# 221     4370293   2628891.0        546509
# 222     4370294   2628892.0        546511
# 223     4370393   2628969.0        546512
# 224     4370406   2628976.0        546513
# 225     4370407   2628977.0        546514
# 226     4370408   2628978.0        546515
# 227     4370409   2628979.0        546516
# 228     4370467   2629136.0        546522
#
# [10 rows x 38 columns]

# %%
df.maloy.value_counts()
#most of the trades are done with small organizations
# Out:
# Y    157036
# N      1924
# Name: maloy, dtype: int64

# %%
df.etp_id.value_counts()
# Out:
# 1    157031
# 3      1924
# 2         5
# Name: etp_id, dtype: int64

# %%
#plot etp_id with its values
plt.figure(figsize=(10, 5))
sns.countplot(x=df.etp_id, data=df)
plt.xticks(rotation=90)
#show numbers on top of bars
for p in plt.gca().patches:
    plt.gca().annotate('{:.0f}'.format(p.get_height()), (p.get_x()+p.get_width()/2., p.get_height()), 
                       ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.title('Количество контрактов по торговой площадке')
#change x axis labels
plt.gca().set_xticklabels(['UZEX', 'XT-XARID','COOPERATION'])
#use seaborn style
sns.set_style("whitegrid")
#use green color
sns.set_palette("Greens_d")

# %%
#which month has the highest summa 
df.groupby(months)['summa'].sum().sort_values(ascending=False)
# Out:
# contract_dat
# Авг    43983484465038
# Сен    39986639208150
# Окт    30706922827643
# Июл     5040397174117
# Июн       60406870704
# Мая       59526011917
# Апр       52483503311
# Фев       40670565500
# Мар        7666109300
# Янв         239653700
# Name: summa, dtype: int64

# %%
#which tovar_name has the highest summa
df.groupby('tovar_name')['summa'].sum().sort_values(ascending=False).head(10)
# Out:
# tovar_name
# Моноблок                                       3354360766445
# Персональный компьютер                         3209078988005
# Промышленная швейная машина                    2716020035395
# Машины швейные бытовые                         1775330919964
# Книги печатные                                 1760188741049
# Бумага для офисной техники белая               1687365663066
# Ноутбук                                        1321758881039
# Услуга по разработке проектно-сметных работ    1287488913468
# Интерактивная панель                           1272359981844
# Кондиционер бытовой                            1219697028215
# Name: summa, dtype: int64

# %%
#plot highest summa tovar_name


plt.figure(figsize=(10,10))
#change the barplot to horizontal
sns.barplot(y=df.groupby('tovar_name')['summa'].sum().sort_values(ascending=False).head(10).index, x=df.groupby('tovar_name')['summa'].sum().sort_values(ascending=False).head(10).values)
plt.xticks(rotation=90)
#show numbers on top of bars
for p in plt.gca().patches:
    plt.gca().annotate('{:.0f}'.format(p.get_height()), (p.get_x()+p.get_width()/2., p.get_height()), 
                       ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.title('Сумма контрактов по наименованию товара')
sns.despine(left=True, bottom=True)

# %%
#top 1 tovar_name every month.
monthly_tovarname = df.groupby([months, 'tovar_name']).sum().sort_values(by='summa', ascending=False).groupby(level=0).head(1)

# %%
#turn the index into columns
monthly_tovarname = monthly_tovarname.reset_index()

# %%
monthly_tovarname
# Out:
#   contract_dat                                         tovar_name  etp_id  \
# 0          Авг                             Персональный компьютер     429
# 1          Сен                        Промышленная швейная машина     303
# 2          Окт                                           Моноблок     240
# 3          Июл       Стационарный радарный комплекс «LochinKöz-Т»       9
# 4          Апр  Услуга по комплексной экспертизе предпроектной...     212
# 5          Июн           Уличный светильник на солнечных батареях       1
# 6          Фев                                     Газон рулонный       1
# 7          Мая                             ткань хб бязь набивная       3
# 8          Мар                    Услуга по лабораторному анализу       4
# 9          Янв        Услуга по разработке проектно-сметных работ       1
#
#    p_avans  avans_day            lot_id           organ  proc_id  raschot  \
# 0      0.0        0.0  9485622707491476   5321034214652     2574   2145.0
# 1      0.0        0.0  6699635647505062  18337003001192     1818   1515.0
# 2      0.0        0.0  5306642114559029   1387060194126     1440   1200.0
# 3      0.0       45.0    66933024382575      1383000226       18     45.0
# 4      0.0        0.0  4687533748198399  10489972000848     1272   1060.0
# 5      0.0        0.0    22111008442978             132        6      5.0
# 6      0.0        0.0    22111008062050       608000002        6      5.0
# 7      0.0       15.0    22311008117426             132        6     15.0
# 8      0.0        0.0    88444032597249      2340000649       24     20.0
# 9      0.0        0.0    22111008033905       561000097        6      5.0
#
#    spok  ...  fin_year  npos  tovar_amount   tovar_price    tovar_summa  \
# 0  2146  ...  867438.0   429          1942  305342782697  1340882458188
# 1  1826  ...  612666.0   303          3598  116016750212  1228127519833
# 2  1310  ...  485280.0   240          1467  211976895935  1219109504208
# 3    45  ...    6066.0     3             6   91200000000   182700000000
# 4  1447  ...  428664.0   212           212   39367965611    39367965611
# 5     3  ...    2022.0     1           100     193760000    19376000000
# 6     5  ...    2022.0     1          4400       3985700    17537080000
# 7    15  ...    2022.0     1          9600       1725000    16560000000
# 8    14  ...    8088.0     4           222     216400000     1533100000
# 9    15  ...    2022.0     1             1     144653700      144653700
#
#          id       pay_id          summa  response_id    request_id
# 0  38816844  13004528549  1340882458188   1916582276  1.153972e+09
# 1  66170065   9245748076  1228127519833   1542118005  9.328507e+08
# 2  78325488   7357928590  1219109504208   1335524374  8.095102e+08
# 3     31838     90604298   182700000000     12288400  2.475578e+07
# 4  41060413   6251676253    39367965611   1055197414  6.378200e+08
# 5    122146     29890220    19376000000      4611378  2.779956e+06
# 6      1835     29129077    17537080000      4052058  2.431656e+06
# 7    102692     30327167    16560000000      4513946  9.023676e+06
# 8     20235    117251585     1533100000     16286427  9.754725e+06
# 9    367395     29055568      144653700      5747765  3.491867e+06
#
# [10 rows x 25 columns]

# %%
#vendor terr
df.vendor_terr.value_counts()
# Out:
# 18401    8205
# 26266    6768
# 24401    6767
# 26294    6215
# 35401    6024
#          ...
# 26000       5
# 12248       4
# 10233       4
# 12412       4
# 35230       4
# Name: vendor_terr, Length: 219, dtype: int64

# %%
#how many 3 letter, 4 letter, 5 letter, 6 letter codes are there in vendor_terr?
df['vendor_terr'].astype(str).apply(len).value_counts()
# Out:
# 5    131467
# 4     24554
# 1      2939
# Name: vendor_terr, dtype: int64

# %%
df.vendor_terr.value_counts().head(10)
# Out:
# 18401    8205
# 26266    6768
# 24401    6767
# 26294    6215
# 35401    6024
# 22401    5332
# 26262    4700
# 8401     4516
# 6401     4511
# 33401    4506
# Name: vendor_terr, dtype: int64

# %%
df['vendor_terr'] = df['vendor_terr'] + 1700000

# %%
df.vendor_terr.isin(vendor_terr_names.id).value_counts()
# Out:
# True     151744
# False      7216
# Name: vendor_terr, dtype: int64

# %%
df.vendor_terr.value_counts().head(20)
# Out:
# 1718401    8205
# 1726266    6768
# 1724401    6767
# 1726294    6215
# 1735401    6024
# 1722401    5332
# 1726262    4700
# 1708401    4516
# 1706401    4511
# 1733401    4506
# 1730412    3872
# 1712401    3837
# 1710401    3732
# 1714401    3703
# 1714236    3673
# 1730401    3045
# 1703401    3045
# 1700000    2939
# 1726287    2439
# 1726280    2230
# Name: vendor_terr, dtype: int64

# %%
df[df.vendor_terr.isin(vendor_terr_names.id) == False].vendor_terr.value_counts()
# Out:
# 1700000    2939
# 1727269    1270
# 1727294     661
# 1727277     618
# 1727266     511
# 1727290     442
# 1727287     278
# 1727280     193
# 1727273     168
# 1727409      47
# 1703404      31
# 1722205      27
# 1735411      26
# 1726000       5
# Name: vendor_terr, dtype: int64

# %%
#drop all rows where vendor_terr is 1700000
df = df[df.vendor_terr != 1700000]

# %%
#17272 - toshkent viloyati
#1703400 - andijon
#17222 - surxandaryo
#17354 - qoraqalpog'iston
#17260 - toshkent shahri

# %%
df.vendor_terr[df.vendor_terr == 17272]
# Out:
# Series([], Name: vendor_terr, dtype: int64)

# %%
vendor_terr_names.id = vendor_terr_names.id.astype(int)

vendor_terr_names.id.dtype
# Out:
# dtype('int64')

# %%
#when vendor_terr_names starts with 17272, name is toshkent viloyati
df.vendor_terr = df.vendor_terr.astype(str).str.startswith('17272').map({True: 'Toshkent viloyati', False: df.vendor_terr})

# %%
df.vendor_terr = df.vendor_terr.astype(str).str.startswith('1703400').map({True: 'Andijon', False: df.vendor_terr})

# %%
df.vendor_terr = df.vendor_terr.astype(str).str.startswith('17222').map({True: 'Surxandaryo', False: df.vendor_terr})

# %%
df.vendor_terr = df.vendor_terr.astype(str).str.startswith('17354').map({True: 'Qoraqalpog\'iston', False: df.vendor_terr})

# %%
df.vendor_terr = df.vendor_terr.astype(str).str.startswith('17260').map({True: 'Toshkent shahri', False: df.vendor_terr})

# %%
#if df_terr is in vendor_terr_names, then name is vendor_terr_names.name
df.vendor_terr = df.vendor_terr.astype(str).isin(vendor_terr_names.id.astype(str)).map({True: vendor_terr_names.name, False: df.vendor_terr})

# %%
df.vendor_terr.value_counts()
# Out:
# [1712234, 1726266, 1735401, 1727273, 1726280, 1733223, 1724231, 1727269, 1706240, 1718401, 1730412, 1710235, 1706401, 1726280, 1726266, 1703202, 1726287, 1703202, 1726262, 1712401, 1718401, 1708209, 1708209, 1733401, 1718401, 1726262, 1708209, 1718401, 1726287, 1718401, 1726280, 1733401, 1727237, 1703200, 1714224, 1727269, 1722401, 1733406, 1726269, 1726269, 1712401, 1730401, 1727401, 1708209, 1726262, 1733401, 1708212, 1727401, 1727401, 1724401, 1710401, 1730401, 1733401, 1730412, 1710401, 1726269, 1726273, 1726269, 1712401, 1730401, 1727237, 1735401, 1708212, 1718401, 1726290, 1710401, 1708209, 1727269, 1726262, 1733401, 1726294, 1726262, 1727280, 1726273, 1726273, 1727248, 1726269, 1712401, 1726287, 1724401, 1727237, 1726294, 1730401, 1726262, 1726280, 1714207, 1726262, 1733406, 1726264, 1726273, 1708401, 1708401, 1726277, 1726262, 1718401, 1712244, 1733208, 1706403, 1714212, 1733401, ...]    145852
# Toshkent viloyati                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             10169
# Name: vendor_terr, dtype: int64
