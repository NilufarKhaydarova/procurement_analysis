# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
spec_df = pd.read_csv('data/specifications.csv', sep=',')
spec_df.info()
spec_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227341 entries, 0 to 227340
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            227341 non-null  int64
#  1   expense       227341 non-null  int64
#  2   fin_year      227341 non-null  int64
#  3   kls           151180 non-null  object
#  4   npos          227341 non-null  int64
#  5   tovar         227341 non-null  object
#  6   tovar_amount  227341 non-null  int64
#  7   tovar_edizm   227288 non-null  object
#  8   tovar_name    227323 non-null  object
#  9   tovar_note    9396 non-null    object
#  10  tovar_price   227341 non-null  int64
#  11  tovar_summa   227341 non-null  int64
# dtypes: int64(7), object(5)
# memory usage: 20.8+ MB
#    id   expense  fin_year                          kls  npos  \
# 0   1  44232200      2022  100022860102327092100075118     1
# 1   2  44821190      2022  305122860102337109602018001     1
# ...

# %%
spec_df.nunique()
# Out:
# id              227341
# expense            126
# fin_year             3
# kls              12583
# npos               198
# tovar             5992
# tovar_amount      5159
# tovar_edizm        104
# tovar_name        6153
# tovar_note        2822
# tovar_price      29911
# tovar_summa      42934
# dtype: int64

# %%
spec_df['expense'].value_counts()
# Out:
# 44252300    37150
# 44252110    27601
# 44252410    25028
# 44299990    16981
# 44221000    11415
# 44252411     9902
# 44292200     7466
# 44252412     7139
# 44252500     6540
# 44354990     5757
# 44821190     5642
# 44293000     4935
# 44224000     4720
# 44354910     4405
# 44234100     4009
# 44239000     3748
# 44252120     3409
# 44233100     3314
# 44292100     2914
# 44225000     2633
# 44355300     2578
# 44354920     2461
# 44234920     2110
# 44232200     2087
# 34322900     1875
# 44252413     1832
# 44252200     1696
# 44252430     1487
# 34321200     1248
# 44222000     1172
# 44234990     1152
# 44233900      809
# 44331200      716
# 44291000      705
# 44332900      678
# 44722300      610
# 34311200      591
# 24121200      571
# 44252440      555
# 44252130      553
# 44223000      534
# 34390300      484
# 34312900      481
# 44339000      460
# 34312110      431
# 44242200      380
# 44721400      372
# 44355100      324
# 44355900      302
# 44211000      283
# ...

# %%
spec_df['tovar_name'].value_counts()
# Out:
# Услуги по передаче электроэнергии                                                      11654
# Услуга оказание охранных услуг на договорной основе юридическим лицам                   4769
# Услуга по разработке проектно-сметных работ                                             3198
# Услуга по подключению к интернету                                                       2748
# Услуга по текущему ремонту автомобильных дорог                                          2647
#                                                                                        ...
# Алюминиевые офсетные пластины                                                              1
# Осветитель                                                                                 1
# Механизм тяговый для фуникулера                                                            1
# SUL-400A Cuvvete FL Complete (Реакционная кювета для CA-104 в комплекте c CuvCard )        1
# ...

# %%
spec_df['tovar_name'].nunique()
# Out:
# 6153

# %%
#show all tovar_name with value_counts 1 
tovar_name = []
tovar_name = spec_df['tovar_name'].value_counts()[spec_df['tovar_name'].value_counts() == 1]

# %%
print(str(tovar_name))
# Out:
# Услуги по аренде мебели                                                                                                                                                                                                                                       1
# Надбавка за стоки                                                                                                                                                                                                                                             1
# Тюнер                                                                                                                                                                                                                                                         1
# ...

# %%
spec_df['tovar_amount'].groupby(spec_df['tovar_name']).sum()
# Out:
# tovar_name
# (Althaeae Medicinal herb Extract*                                                                                                                                                       250
# (Вакцина 10-валентная пневмококковой полисахаридная, конъюгированная с D-протеином нетипируемой Haemophilus influenzae, столбнячным и дифтерийным анатоксинами, адсорбированная)*       800
# 12 АА 121444-121543 Бланк свидетельства                                                                                                                                                 100
# 15 АА 637103-637250  645251-645382 Бланк свидетельства                                                                                                                                  280
# 19 АА 349001-349075 Бланк свидетельства                                                                                                                                                  75
# ...

# %%
spec_df.sort_values(by='tovar_summa',ascending=False).head(10)
# Out:
#              id   expense  fin_year                          kls  npos  \
# 87214     87118  34311200      2022  100021860274017096521075100     1
# 209284  1087431  44291000      2022  200221860272537018514237001     1
# 153940   556968  44821190      2022  470010860242207045193118001     1
# 139098   139089  44221000      2022  100021860102357042402170002     3
# 141113   141105  44221000      2022  100021860102357042402170002     3
# 139099   139090  44221000      2022  100021860102357042402170002     4
# 222854  1101037  44221000         0                          NaN     1
# 141114   141106  44221000      2022  100021860102357042402170002     4
# 169983  1048170  44221000      2022  100010860062047042402170005     3
# 198107  1076281  44221000         0                          NaN     3
#
#                      tovar  tovar_amount tovar_edizm  \
# 87214   71.12.12.130-00004      35000000           0
# 209284  85.42.19.900-00009        660000           0
# ...

# %%
spec_df['tovar_note'].nunique()
# Out:
# 2822

# %%
#show tovar_name with tovar_note
spec_df[spec_df['tovar_note'].notnull()]['tovar_name'].value_counts()
# Out:
# Строительно монтажные работы                                                                                                                                                                                                         1331
# Услуга по текущему ремонту автомобильных дорог                                                                                                                                                                                       1220
# Работы строительные по реконструкции зданий                                                                                                                                                                                           485
# Стол ученический                                                                                                                                                                                                                      449
# ...

# %%
#drop tovar_name with nan values
spec_df = spec_df[spec_df['tovar_name'].notnull()]

# %%
#tovar_name with latin symbols only 
medicine = []
medicine  = spec_df[spec_df['tovar_name'].str.contains('^[a-zA-Z ]+$')]['tovar_name'].value_counts()

# %%
#replace with Медицинские изделия for tovar_name with latin symbols only
spec_df['tovar_name'] = spec_df['tovar_name'].replace(medicine.index, 'Медицинские изделия')
# Out:
# /var/folders/fh/yq61fqcs3q9_0k81sxnf4ff40000gn/T/ipykernel_43989/1976808588.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spec_df['tovar_name'] = spec_df['tovar_name'].replace(medicine.index, 'Медицинские изделия')

# %%
spec_df.head(10)
# Out:
#    id   expense  fin_year                          kls  npos  \
# 0   1  44232200      2022  100022860102327092100075118     1
# 1   2  44821190      2022  305122860102337109602018001     1
# 2   3  44252110         0                          NaN     1
# 3   4  44252110         0                          NaN     1
# 4   5  44252110         0                          NaN     1
# 5   6  44252110         0                          NaN     1
# 6   7  44354920         0                          NaN     1
# 7   8  44252110         0                          NaN     1
# 8   9  44239000         0                          NaN     1
# 9  10  44239000         0                          NaN     1
#
#                 tovar  tovar_amount tovar_edizm  \
# 0  41.20.40.900-00006             1           0
# 1  43.39.19.190-00007             1           0
# 2  17.23.13.193-00005            80           0
# 3  13.20.44.120-00001            30           2
# ...

# %%
spec_df['kls'].nunique()
# Out:
# 12583

# %%
spec_df['kls'].value_counts()
# Out:
# 100010860262667096511075025    792
# 100021860274077042204142001    734
# 400522860184017091100251001    585
# 100022860102507073101054009    461
# 300410860262667096421218001    459
#                               ...
# 304521860104017045129118232      1
# 304510860144017045193118001      1
# 304521860104017045129118233      1
# 400122860032037042402170001      1
# 301821860184017091100251022      1
# Name: kls, Length: 12583, dtype: int64

# %%
claim_spec = pd.read_csv('data/claim_info_etp_specifications.csv', sep=',')
claim_spec.info()
claim_spec.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6873 entries, 0 to 6872
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   claim_info_etp_id  6873 non-null   int64
#  1   specifications_id  6873 non-null   int64
# dtypes: int64(2)
# memory usage: 107.5 KB
#    claim_info_etp_id  specifications_id
# 0                  1                  1
# 1                  2                  2
# 2                  3                 80
# 3                  4                 86
# 4                  5                 89
# 5                  6                188
# 6                  7                266
# 7                  8                279
# 8                  8                280
# 9                  8                281
